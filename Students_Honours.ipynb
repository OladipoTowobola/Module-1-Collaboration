# %%
## Name: Towobola Oladipo
## File Name: student_honours.py
## Description: This application accepts student names and GPAs, 
##then determines whether each student qualifies for the Dean's List or Honor Roll.

# %%
while True:
    last_name = input("Enter student's last name (or 'ZZZ' to quit): ").strip()

    if last_name.upper() == "ZZZ":
        print("Exiting program.")
        break

    ## Ask for and accept the student's first name
    first_name = input("Enter student's first name:")

    ## Ask for the student's GPA as a float.
    try:
        gpa = float(input("Enter Student's GPA: "))
    except ValueError:
        print("Invalid GPA entered. Please enter a numeric value.")
        continue

    ## Test if the student's GPA is 3.5 or greater check for Dean's List
    if gpa >= 3.5:
        print(f"{first_name} {last_name} has made the Dean's List.")

    ## Check for Honor Roll
    elif gpa >= 3.25:
        print(f"{first_name} {last_name} has made the Honor Roll.")

    else:
        print(f"{first_name} {last_name} did not qualify for honors.")

    ## Blank line for readability    
    print()
# Out:
# Enter student's last name (or 'ZZZ' to quit):  John
# Enter student's first name: Smith
# Enter Student's GPA:  3.8
# Smith John has made the Dean's List.
# Enter student's last name (or 'ZZZ' to quit):  Mary
# Enter student's first name: Jones
# Enter Student's GPA:  3.4
# Jones Mary has made the Honor Roll.
# Enter student's last name (or 'ZZZ' to quit):  Alex
# Enter student's first name: Brown
# Enter Student's GPA:  3.2
# Brown Alex did not qualify for honors.
# Enter student's last name (or 'ZZZ' to quit):  Lisa
# Enter student's first name: White
# Enter Student's GPA:  2.9
# White Lisa did not qualify for honors.
# Enter student's last name (or 'ZZZ' to quit):  Mark
# Enter student's first name: Green
# Enter Student's GPA:  3.5
# Green Mark has made the Dean's List.
# Enter student's last name (or 'ZZZ' to quit):  ZZZ
# Exiting program.
